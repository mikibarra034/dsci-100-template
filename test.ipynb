# %%
library(tidyverse)
# Out:
# Warning message in system("timedatectl", intern = TRUE):
# “running command 'timedatectl' had status 1”
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.2 ──
# ✔ ggplot2 3.3.6     ✔ purrr   0.3.4
# ✔ tibble  3.1.8     ✔ dplyr   1.0.9
# ✔ tidyr   1.2.0     ✔ stringr 1.4.1
# ✔ readr   2.1.2     ✔ forcats 0.5.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()

# %%
names = c("Age","Sex", "p","Trestbps", "Chol", "Fbs", "Restecg", "Thalach", "Exang", "Oldpeak", "Slope", "Ca", "Thal", "Num")
df_switzerland <- read_delim("Data/processed.switzerland.data", ",", col_names = names)
df_switzerland[df_switzerland == "?"] <- NA
df_switzerland
nrow(df_switzerland)
# Out:
# Rows: 123 Columns: 14
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (9): Trestbps, Fbs, Restecg, Thalach, Exang, Oldpeak, Slope, Ca, Thal
# dbl (5): Age, Sex, p, Chol, Num
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#     Age Sex p Trestbps Chol Fbs Restecg Thalach Exang Oldpeak Slope Ca Thal Num
# 1   32  1   1 95       0    NA  0       127     0     .7      1     NA NA   1
# 2   34  1   4 115      0    NA  NA      154     0     .2      1     NA NA   1
# 3   35  1   4 NA       0    NA  0       130     1     NA      NA    NA 7    3
# 4   36  1   4 110      0    NA  0       125     1     1       2     NA 6    1
# 5   38  0   4 105      0    NA  0       166     0     2.8     1     NA NA   2
# 6   38  0   4 110      0    0   0       156     0     0       2     NA 3    1
# 7   38  1   3 100      0    NA  0       179     0     -1.1    1     NA NA   0
# 8   38  1   3 115      0    0   0       128     1     0       2     NA 7    1
# 9   38  1   4 135      0    NA  0       150     0     0       NA    NA 3    2
# 10  38  1   4 150      0    NA  0       120     1     NA      NA    NA 3    1
# 11  40  1   4 95       0    NA  1       144     0     0       1     NA NA   2
# 12  41  1   4 125      0    NA  0       176     0     1.6     1     NA NA   2
# 13  42  1   4 105      0    NA  0       128     1     -1.5    3     NA NA   1
# 14  42  1   4 145      0    0   0       99      1     0       2     NA NA   2
# 15  43  1   4 100      0    NA  0       122     0     1.5     3     NA NA   3
# 16  43  1   4 115      0    0   0       145     1     2       2     NA 7    4
# 17  43  1   4 140      0    0   1       140     1     .5      1     NA 7    2
# 18  45  1   3 110      0    NA  0       138     0     -.1     1     NA NA   0
# 19  46  1   4 100      0    NA  1       133     0     -2.6    2     NA NA   1
# 20  46  1   4 115      0    0   0       113     1     1.5     2     NA 7    1
# 21  47  1   3 110      0    NA  0       120     1     0       NA    NA 3    1
# 22  47  1   3 155      0    0   0       118     1     1       2     NA 3    3
# 23  47  1   4 110      0    NA  1       149     0     2.1     1     NA NA   2
# 24  47  1   4 160      0    0   0       124     1     0       2     NA 7    1
# 25  48  1   4 115      0    NA  0       128     0     0       2     NA 6    2
# 26  50  0   4 160      0    NA  0       110     0     0       NA    NA 3    1
# 27  50  1   4 115      0    0   0       120     1     .5      2     NA 6    3
# 28  50  1   4 120      0    0   1       156     1     0       1     NA 6    3
# 29  50  1   4 145      0    NA  0       139     1     .7      2     NA NA   1
# 30  51  0   4 120      0    NA  0       127     1     1.5     1     NA NA   2
# ⋮   ⋮   ⋮   ⋮ ⋮        ⋮    ⋮   ⋮       ⋮       ⋮     ⋮       ⋮     ⋮  ⋮    ⋮
# 94  62  0   4 120      0    NA  1       123     1     1.7     3     NA NA   1
# 95  62  1   1 120      0    NA  2       134     0     -.8     2     2  NA   1
# 96  62  1   3 160      0    0   0       72      1     0       2     NA 3    3
# 97  62  1   4 115      0    NA  0       128     1     2.5     3     NA NA   2
# 98  62  1   4 115      0    NA  0       72      1     -.5     2     NA 3    1
# 99  62  1   4 150      0    NA  1       78      0     2       2     NA 7    3
# 100 63  1   4 100      0    NA  0       109     0     -.9     2     NA NA   1
# 101 63  1   4 140      0    NA  2       149     0     2       1     NA NA   2
# 102 63  1   4 150      0    0   0       86      1     2       2     NA NA   3
# 103 63  1   4 150      0    NA  1       154     0     3.7     1     NA NA   3
# 104 63  1   4 185      0    0   0       98      1     0       1     NA 7    1
# 105 64  0   4 200      0    0   0       140     1     1       2     NA 3    3
# 106 64  0   4 95       0    NA  0       145     0     1.1     3     NA NA   1
# 107 64  1   4 110      0    NA  0       114     1     1.3     3     NA NA   1
# 108 65  1   4 115      0    0   0       93      1     0       2     NA 7    1
# 109 65  1   4 145      0    NA  1       67      0     NA      NA    NA 6    3
# 110 65  1   4 155      0    NA  0       154     0     1       1     NA NA   0
# 111 65  1   4 160      0    1   1       122     0     NA      NA    NA 7    3
# 112 66  0   4 155      0    NA  0       90      0     0       NA    NA 7    1
# 113 66  1   4 150      0    0   0       108     1     2       2     NA 7    3
# 114 67  1   1 145      0    0   2       125     0     0       2     NA 3    2
# 115 68  1   4 135      0    0   1       120     1     0       1     NA 7    3
# 116 68  1   4 145      0    NA  0       136     0     1.8     1     NA NA   1
# 117 69  1   4 135      0    0   0       130     0     0       2     NA 6    1
# 118 69  1   4 NA       0    0   1       NA      NA    NA      NA    NA 7    3
# 119 70  1   4 115      0    0   1       92      1     0       2     NA 7    1
# 120 70  1   4 140      0    1   0       157     1     2       2     NA 7    3
# 121 72  1   3 160      0    NA  2       114     0     1.6     2     2  NA   0
# 122 73  0   3 160      0    0   1       121     0     0       1     NA 3    1
# 123 74  1   2 145      0    NA  1       123     0     1.3     1     NA NA   1
# [1] 123

# %%
df_va <- read_delim("Data/processed.va.data", ",", col_names = names)
df_va[df_va == "?"] <- NA
df_va
nrow(df_va)
# Out:
# Rows: 200 Columns: 14
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (9): Trestbps, Chol, Fbs, Thalach, Exang, Oldpeak, Slope, Ca, Thal
# dbl (5): Age, Sex, p, Restecg, Num
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#     Age Sex p Trestbps Chol Fbs Restecg Thalach Exang Oldpeak Slope Ca Thal Num
# 1   63  1   4 140      260  0   1       112     1     3       2     NA NA   2
# 2   44  1   4 130      209  0   1       127     0     0       NA    NA NA   0
# 3   60  1   4 132      218  0   1       140     1     1.5     3     NA NA   2
# 4   55  1   4 142      228  0   1       149     1     2.5     1     NA NA   1
# 5   66  1   3 110      213  1   2       99      1     1.3     2     NA NA   0
# 6   66  1   3 120      0    0   1       120     0     -0.5    1     NA NA   0
# 7   65  1   4 150      236  1   1       105     1     0       NA    NA NA   3
# 8   60  1   3 180      0    0   1       140     1     1.5     2     NA NA   0
# 9   60  1   3 120      0    NA  0       141     1     2       1     NA NA   3
# 10  60  1   2 160      267  1   1       157     0     0.5     2     NA NA   1
# 11  56  1   2 126      166  0   1       140     0     0       NA    NA NA   0
# 12  59  1   4 140      0    0   1       117     1     1       2     NA NA   1
# 13  62  1   4 110      0    0   0       120     1     0.5     2     NA 3    1
# 14  63  1   3 NA       0    0   2       NA      NA    NA      NA    NA NA   1
# 15  57  1   4 128      0    1   1       148     1     1       2     NA NA   1
# 16  62  1   4 120      220  0   1       86      0     0       NA    NA NA   0
# 17  63  1   4 170      177  0   0       84      1     2.5     3     NA NA   4
# 18  46  1   4 110      236  0   0       125     1     2       2     NA NA   1
# 19  63  1   4 126      0    0   1       120     0     1.5     3     NA NA   0
# 20  60  1   4 152      0    0   1       118     1     0       NA    NA 7    0
# 21  58  1   4 116      0    0   0       124     0     1       1     NA NA   2
# 22  64  1   4 120      0    1   1       106     0     2       2     NA NA   1
# 23  63  1   3 130      0    0   1       111     1     0       NA    NA NA   3
# 24  74  1   3 NA       0    0   0       NA      NA    NA      NA    NA NA   0
# 25  52  1   3 128      0    0   1       180     0     3       1     NA NA   2
# 26  69  1   4 130      0    1   1       129     0     1       2     NA 6    2
# 27  51  1   4 NA       0    1   1       NA      NA    NA      NA    NA NA   2
# 28  60  1   4 130      186  1   1       140     1     0.5     2     NA NA   1
# 29  56  1   4 120      100  0   0       120     1     1.5     2     0  7    1
# 30  55  1   3 NA       228  0   1       NA      NA    NA      NA    NA NA   3
# ⋮   ⋮   ⋮   ⋮ ⋮        ⋮    ⋮   ⋮       ⋮       ⋮     ⋮       ⋮     ⋮  ⋮    ⋮
# 171 53  1   4 124      243  0   0       122     1     2       2     NA 7    1
# 172 37  1   3 118      240  0   2       165     0     1       2     NA 3    0
# 173 67  1   4 140      219  0   1       122     1     2       2     NA 7    3
# 174 74  1   3 140      237  1   0       94      0     0       NA    NA NA   1
# 175 63  1   2 NA       165  0   1       NA      NA    NA      NA    NA NA   0
# 176 58  1   4 100      213  0   1       110     0     0       NA    NA NA   0
# 177 61  1   4 190      287  1   2       150     1     2       3     NA NA   4
# 178 64  1   4 130      258  1   2       130     0     0       NA    NA 6    2
# 179 58  1   4 160      256  1   2       113     1     1       1     NA NA   3
# 180 60  1   4 130      186  1   2       140     1     0.5     2     NA NA   1
# 181 57  1   4 122      264  0   2       100     0     0       NA    NA NA   1
# 182 55  1   3 NA       NA   0   1       NA      NA    NA      NA    NA NA   0
# 183 55  1   4 120      226  0   2       127     1     1.7     3     NA 7    1
# 184 56  1   4 130      203  1   0       98      0     1.5     2     NA 7    1
# 185 57  1   4 130      207  0   1       96      1     1       2     NA NA   0
# 186 61  1   3 NA       284  0   0       NA      NA    NA      NA    NA NA   1
# 187 61  1   3 120      337  0   0       98      1     0       NA    NA NA   3
# 188 58  1   3 150      219  0   1       118     1     0       NA    NA NA   2
# 189 74  1   4 155      310  0   0       112     1     1.5     3     NA NA   2
# 190 68  1   3 134      254  1   0       151     1     0       NA    NA 3    0
# 191 51  0   4 114      258  1   2       96      0     1       1     NA NA   0
# 192 62  1   4 160      254  1   1       108     1     3       2     NA NA   4
# 193 53  1   4 144      300  1   1       128     1     1.5     2     NA NA   3
# 194 62  1   4 158      170  0   1       138     1     0       NA    NA NA   1
# 195 46  1   4 134      310  0   0       126     0     0       NA    NA 3    2
# 196 54  0   4 127      333  1   1       154     0     0       NA    NA NA   1
# 197 62  1   1 NA       139  0   1       NA      NA    NA      NA    NA NA   0
# 198 55  1   4 122      223  1   1       100     0     0       NA    NA 6    2
# 199 58  1   4 NA       385  1   2       NA      NA    NA      NA    NA NA   0
# 200 62  1   2 120      254  0   2       93      1     0       NA    NA NA   1
# [1] 200

# %%
merged_frame <- merge(df_switzerland,df_va,by = names)
merged_frame
# Out:
#      Age Sex p Trestbps Chol Fbs Restecg Thalach Exang Oldpeak Slope Ca Thal
#      Num
